# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import random
# %matplotlib inline

# %% [markdown]
# - Use algún método de interpolación en una malla regular,Voronoi por ejemplo
# - Calcule la Transformada de Fourier de la señal regularmente remuestreada
# - descarte las altas frecuencias
# - Calcule la Transformada de Fourier inversa para producir el estimado f1
# - Calcule el error f (n) − f1 (n), para1, . . . , N
# - Interpole el error usando el método escogido y use este error estimado en cada punto para estimar f2 (n)...
# - Itere recalculando la Transformada de Fourier

# %%
image = cv2.imread('SFE.png',flags=cv2.IMREAD_GRAYSCALE)
plt.imshow(image,cmap='gray')

# %%
H,W = image.shape
print(H,W)
# Out:
# 240 240

# %%
image[H-1][W-1]
# Out:
# 98

# %%
# return an array of random points(x,y) where x<=max_width and b<=max_height
def get_random_points(max_height,max_width,quantity):
    points = np.zeros(quantity,dtype=object)
    for i in range(quantity):
        x_coord = random.randint(0,max_width-1)
        y_coord = random.randint(0,max_height-1)
        points[i]=(x_coord,y_coord)
    return points
# returns the irregular sampled image and the points used to evalute the value of the image    
def get_irregular_sampling(image,number_of_points):
    height , width = image.shape
    irregular_sampled_image = np.zeros(shape=(height,width))
    image_values=[]
    random_points = get_random_points(height,width,number_of_points)
    
    for i in range(number_of_points):
        x,y = random_points[i]
        irregular_sampled_image[y][x]=image[y][x]
        image_values.append(image[y][x])
    return irregular_sampled_image,random_points,image_values

# %%
i_sampled_image,i_points,i_values = get_irregular_sampling(image,1000)
plt.imshow(i_sampled_image,cmap='gray')

# %%
# returns an array of cartesian points
def get_points(max_height,max_width):
    points = []
    for i in range(max_height):
        for j in range(max_width):
            points.append((i,j))
    return points

p = get_points(H,W)

# %%
# Out:
# [98,
#  98,
#  98,
#  98,
#  98,
#  253,
#  98,
#  254,
#  98,
#  147,
#  255,
#  254,
#  98,
#  147,
#  98,
#  147,
#  147,
#  147,
#  98,
#  98,
#  254,
#  254,
#  254,
#  254,
#  98,
#  147,
#  255,
#  98,
#  255,
#  98,
#  254,
#  203,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  147,
#  98,
#  147,
#  245,
#  254,
#  254,
#  254,
#  98,
#  147,
#  254,
#  254,
#  98,
#  147,
#  255,
#  147,
#  254,
#  147,
#  98,
#  147,
#  254,
#  98,
#  254,
#  98,
#  254,
#  98,
#  254,
#  98,
#  254,
#  149,
#  254,
#  254,
#  98,
#  251,
#  98,
#  98,
#  98,
#  98,
#  147,
#  98,
#  147,
#  254,
#  147,
#  254,
#  254,
#  219,
#  172,
#  147,
#  98,
#  147,
#  255,
#  98,
#  254,
#  254,
#  252,
#  98,
#  98,
#  254,
#  98,
#  98,
#  98,
#  98,
#  254,
#  254,
#  254,
#  147,
#  98,
#  147,
#  254,
#  147,
#  185,
#  254,
#  98,
#  147,
#  98,
#  147,
#  98,
#  147,
#  98,
#  98,
#  254,
#  154,
#  147,
#  254,
#  98,
#  150,
#  98,
#  98,
#  254,
#  147,
#  254,
#  98,
#  98,
#  147,
#  187,
#  147,
#  254,
#  98,
#  98,
#  254,
#  254,
#  98,
#  255,
#  175,
#  254,
#  98,
#  98,
#  147,
#  254,
#  98,
#  147,
#  254,
#  254,
#  98,
#  251,
#  254,
#  98,
#  254,
#  254,
#  254,
#  98,
#  98,
#  147,
#  98,
#  254,
#  147,
#  255,
#  255,
#  147,
#  98,
#  98,
#  254,
#  252,
#  254,
#  98,
#  254,
#  98,
#  255,
#  254,
#  98,
#  255,
#  254,
#  98,
#  147,
#  254,
#  254,
#  98,
#  255,
#  252,
#  255,
#  98,
#  98,
#  98,
#  98,
#  254,
#  254,
#  255,
#  254,
#  254,
#  154,
#  147,
#  254,
#  254,
#  98,
#  98,
#  98,
#  255,
#  254,
#  253,
#  98,
#  254,
#  98,
#  254,
#  254,
#  147,
#  98,
#  147,
#  147,
#  254,
#  98,
#  98,
#  254,
#  254,
#  254,
#  98,
#  98,
#  254,
#  98,
#  254,
#  98,
#  254,
#  98,
#  98,
#  147,
#  98,
#  147,
#  254,
#  254,
#  98,
#  254,
#  254,
#  98,
#  98,
#  98,
#  254,
#  254,
#  251,
#  255,
#  254,
#  255,
#  98,
#  167,
#  254,
#  242,
#  98,
#  98,
#  254,
#  98,
#  98,
#  98,
#  98,
#  98,
#  254,
#  98,
#  147,
#  98,
#  147,
#  254,
#  147,
#  147,
#  98,
#  252,
#  254,
#  170,
#  98,
#  254,
#  147,
#  98,
#  252,
#  98,
#  98,
#  153,
#  98,
#  254,
#  98,
#  254,
#  147,
#  254,
#  98,
#  98,
#  98,
#  170,
#  254,
#  254,
#  255,
#  254,
#  253,
#  254,
#  98,
#  252,
#  98,
#  98,
#  254,
#  254,
#  98,
#  98,
#  98,
#  147,
#  98,
#  98,
#  98,
#  254,
#  98,
#  98,
#  255,
#  254,
#  255,
#  147,
#  147,
#  252,
#  98,
#  98,
#  98,
#  98,
#  98,
#  147,
#  98,
#  98,
#  252,
#  254,
#  147,
#  252,
#  98,
#  98,
#  98,
#  209,
#  98,
#  147,
#  254,
#  254,
#  98,
#  147,
#  147,
#  147,
#  98,
#  98,
#  98,
#  147,
#  254,
#  147,
#  98,
#  147,
#  254,
#  147,
#  254,
#  253,
#  254,
#  254,
#  254,
#  254,
#  98,
#  98,
#  251,
#  254,
#  254,
#  254,
#  147,
#  98,
#  147,
#  254,
#  187,
#  254,
#  147,
#  254,
#  147,
#  98,
#  254,
#  147,
#  254,
#  98,
#  98,
#  98,
#  98,
#  252,
#  228,
#  254,
#  254,
#  189,
#  147,
#  98,
#  98,
#  98,
#  98,
#  98,
#  254,
#  254,
#  254,
#  98,
#  254,
#  254,
#  254,
#  98,
#  98,
#  254,
#  98,
#  98,
#  98,
#  98,
#  254,
#  98,
#  98,
#  254,
#  254,
#  254,
#  254,
#  147,
#  147,
#  254,
#  254,
#  147,
#  254,
#  254,
#  98,
#  98,
#  254,
#  98,
#  98,
#  254,
#  98,
#  254,
#  147,
#  147,
#  254,
#  254,
#  254,
#  98,
#  98,
#  98,
#  98,
#  254,
#  200,
#  147,
#  98,
#  254,
#  254,
#  254,
#  147,
#  98,
#  98,
#  201,
#  213,
#  98,
#  254,
#  98,
#  147,
#  147,
#  98,
#  154,
#  147,
#  254,
#  254,
#  98,
#  254,
#  253,
#  147,
#  162,
#  254,
#  98,
#  149,
#  254,
#  98,
#  147,
#  147,
#  147,
#  254,
#  147,
#  255,
#  98,
#  98,
#  98,
#  98,
#  147,
#  98,
#  251,
#  254,
#  98,
#  219,
#  147,
#  254,
#  147,
#  254,
#  252,
#  254,
#  98,
#  98,
#  252,
#  147,
#  147,
#  98,
#  147,
#  223,
#  254,
#  147,
#  224,
#  242,
#  252,
#  255,
#  98,
#  252,
#  254,
#  255,
#  147,
#  254,
#  253,
#  98,
#  147,
#  254,
#  147,
#  98,
#  254,
#  147,
#  147,
#  160,
#  98,
#  255,
#  254,
#  254,
#  254,
#  150,
#  98,
#  98,
#  254,
#  254,
#  254,
#  98,
#  98,
#  98,
#  254,
#  98,
#  98,
#  98,
#  180,
#  254,
#  254,
#  98,
#  254,
#  254,
#  147,
#  98,
#  147,
#  254,
#  98,
#  254,
#  98,
#  253,
#  164,
#  254,
#  254,
#  147,
#  254,
#  98,
#  147,
#  254,
#  147,
#  254,
#  254,
#  254,
#  147,
#  98,
#  98,
#  254,
#  147,
#  147,
#  254,
#  98,
#  254,
#  147,
#  254,
#  147,
#  254,
#  254,
#  98,
#  147,
#  147,
#  98,
#  98,
#  98,
#  255,
#  254,
#  254,
#  254,
#  254,
#  254,
#  147,
#  254,
#  147,
#  98,
#  183,
#  147,
#  255,
#  147,
#  254,
#  254,
#  147,
#  98,
#  98,
#  254,
#  98,
#  254,
#  251,
#  254,
#  98,
#  98,
#  147,
#  98,
#  255,
#  254,
#  98,
#  254,
#  147,
#  98,
#  255,
#  147,
#  254,
#  254,
#  147,
#  254,
#  98,
#  150,
#  254,
#  254,
#  254,
#  254,
#  254,
#  98,
#  254,
#  254,
#  98,
#  254,
#  255,
#  147,
#  147,
#  253,
#  147,
#  254,
#  254,
#  147,
#  98,
#  147,
#  147,
#  254,
#  254,
#  254,
#  254,
#  254,
#  98,
#  255,
#  98,
#  147,
#  253,
#  147,
#  252,
#  255,
#  98,
#  98,
#  254,
#  159,
#  98,
#  254,
#  98,
#  219,
#  252,
#  254,
#  98,
#  98,
#  254,
#  98,
#  98,
#  254,
#  98,
#  252,
#  252,
#  254,
#  255,
#  148,
#  252,
#  98,
#  98,
#  251,
#  255,
#  98,
#  147,
#  254,
#  147,
#  98,
#  255,
#  254,
#  98,
#  254,
#  147,
#  254,
#  254,
#  98,
#  255,
#  212,
#  147,
#  219,
#  98,
#  147,
#  98,
#  98,
#  98,
#  98,
#  255,
#  255,
#  147,
#  98,
#  98,
#  98,
#  98,
#  254,
#  254,
#  98,
#  254,
#  98,
#  254,
#  98,
#  254,
#  147,
#  254,
#  254,
#  255,
#  255,
#  151,
#  254,
#  254,
#  98,
#  147,
#  240,
#  254,
#  98,
#  147,
#  254,
#  98,
#  98,
#  98,
#  98,
#  254,
#  98,
#  98,
#  254,
#  147,
#  147,
#  98,
#  98,
#  255,
#  98,
#  254,
#  98,
#  255,
#  253,
#  147,
#  98,
#  147,
#  254,
#  254,
#  254,
#  254,
#  98,
#  147,
#  254,
#  98,
#  147,
#  147,
#  254,
#  254,
#  98,
#  255,
#  254,
#  254,
#  98,
#  254,
#  98,
#  98,
#  98,
#  254,
#  153,
#  254,
#  254,
#  147,
#  98,
#  255,
#  253,
#  98,
#  147,
#  147,
#  254,
#  254,
#  254,
#  98,
#  147,
#  98,
#  254,
#  98,
#  254,
#  154,
#  98,
#  254,
#  98,
#  254,
#  98,
#  254,
#  98,
#  254,
#  147,
#  98,
#  147,
#  147,
#  147,
#  98,
#  98,
#  254,
#  254,
#  98,
#  171,
#  254,
#  147,
#  147,
#  255,
#  98,
#  147,
#  254,
#  147,
#  254,
#  254,
#  98,
#  98,
#  98,
#  254,
#  160,
#  255,
#  255,
#  254,
#  254,
#  98,
#  147,
#  147,
#  254,
#  254,
#  147,
#  98,
#  254,
#  98,
#  230,
#  254,
#  255,
#  254,
#  147,
#  254,
#  254,
#  98,
#  98,
#  254,
#  184,
#  98,
#  202,
#  98,
#  254,
#  98,
#  254,
#  98,
#  147,
#  254,
#  147,
#  98,
#  255,
#  98,
#  147,
#  98,
#  254,
#  254,
#  254,
#  147,
#  254,
#  254,
#  254,
#  254,
#  98,
#  254,
#  254,
#  147,
#  98,
#  255,
#  252,
#  255,
#  254,
#  98,
#  98,
#  255,
#  98,
#  221,
#  255,
#  98,
#  98,
#  98,
#  254,
#  255,
#  254,
#  98,
#  153,
#  254,
#  98,
#  98,
#  147,
#  254,
#  255,
#  254,
#  254,
#  242,
#  159,
#  251,
#  254,
#  255,
#  98,
#  98,
#  254,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  98,
#  98,
#  98,
#  254,
#  183,
#  254,
#  147,
#  254,
#  98,
#  254,
#  254,
#  254,
#  98,
#  98,
#  254,
#  254,
#  98,
#  98,
#  98,
#  98,
#  254,
#  254,
#  253,
#  147,
#  254,
#  147,
#  147,
#  147,
#  254,
#  254,
#  254,
#  98,
#  254,
#  255,
#  255,
#  147,
#  254,
#  254,
#  98,
#  254,
#  98,
#  254,
#  98,
#  160,
#  147,
#  147,
#  98,
#  98,
#  254,
#  254,
#  98,
#  98,
#  254,
#  147,
#  147,
#  98,
#  254,
#  254,
#  98,
#  254,
#  98,
#  254,
#  254,
#  98,
#  147,
#  251,
#  98,
#  253,
#  254,
#  147,
#  98]

# %%
from scipy.interpolate import NearestNDInterpolator


#interpolation = NearestNDInterpolator(p,i_sampled_image.flatten())
interpolation = NearestNDInterpolator(i_points.tolist(),i_values)

# %%
interpolation((25.3,30.2))
# Out:
# 98

# %%
int_image = np.empty(shape=(H,W))
for i in range(W):
    for j in range(H):
        int_image[j][i]=interpolation((i,j))

# %%
int_image.shape
# Out:
# (240, 240)

# %%
plt.imshow(int_image,cmap='gray')

# %%
from scipy.interpolate import griddata
x = np.arange(0, W, 1)
y = np.arange(0, H, 1)
xx, yy = np.meshgrid(x, y, sparse=True)

# %%
g_interpolation=griddata(i_points.tolist(),np.array(i_values),(xx,yy), method='cubic')

# %%
plt.imshow(g_interpolation,cmap='gray')

# %%
print(g_interpolation)

print(int_image)
# Out:
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# [[98. 98. 98. ... 98. 98. 98.]
#  [98. 98. 98. ... 98. 98. 98.]
#  [98. 98. 98. ... 98. 98. 98.]
#  ...
#  [98. 98. 98. ... 98. 98. 98.]
#  [98. 98. 98. ... 98. 98. 98.]
#  [98. 98. 98. ... 98. 98. 98.]]

# %%
fft= np.fft.fft2(int_image)
fshift = np.fft.fftshift(fft)
magnitude_spectrum = 20*np.log(np.abs(fshift))
plt.imshow(magnitude_spectrum, cmap = 'gray')

# %%
circle_img = np.zeros(shape=(H,W), dtype=np.uint8)
r = H//4
circle_img = cv2.circle(circle_img, (H//2,W//2), r, (255,255,255), -1)
plt.imshow(circle_img,cmap='gray')

# %%
filtered_spectrum = circle_img*fft
plt.imshow(filtered_spectrum,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-345-ebe025065771> in <module>
#       1 filtered_spectrum = circle_img*fft
# ----> 2 plt.imshow(filtered_spectrum,cmap='gray')
#
# ~/Projects/images/env/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/Projects/images/env/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/Projects/images/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/Projects/images/env/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     700         if (self._A.dtype != np.uint8 and
#     701                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 702             raise TypeError("Image data of dtype {} cannot be converted to "
#     703                             "float".format(self._A.dtype))
#     704
#
# TypeError: Image data of dtype complex128 cannot be converted to float

# %%
ifft= np.fft.ifft2(filtered_spectrum)
fshift = np.fft.fftshift(ifft)
magnitude_spectrum = 20*np.log(np.abs(fshift))
plt.imshow(magnitude_spectrum, cmap = 'gray')

# %%
error = i_sampled_image-magnitude_spectrum
plt.imshow(error,cmap='gray')

# %%
hist
# Out:
# array([   48,   530,  8299, 87386, 91397, 10879,  1352,    98,    10,
#            1])
