# %% [markdown]
# # Color Threshold, Green Screen

# %% [markdown]
# ### Import resources

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
import cv2

# %matplotlib inline

# %% [markdown]
# ### Read in and display the image

# %%
# Read in the image
image = mpimg.imread('images/car_green_screen.jpg')

# Print out the image dimensions (height, width, and depth (color))
print('Image dimensions:', image.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8b4ee949d661> in <module>
#       1 # Read in the image
# ----> 2 image = mpimg.imread('images/car_green_screen.jpg')
#       3
#       4 # Print out the image dimensions (height, width, and depth (color))
#       5 print('Image dimensions:', image.shape)
#
# ~/Projects/Image-Processing/env/lib/python3.8/site-packages/matplotlib/image.py in imread(fname, format)
#    1494                     response = io.BytesIO(response.read())
#    1495                 return imread(response, format=ext)
# -> 1496     with img_open(fname) as image:
#    1497         return (_pil_png_to_float_array(image)
#    1498                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~/Projects/Image-Processing/env/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2902
#    2903     if filename:
# -> 2904         fp = builtins.open(filename, "rb")
#    2905         exclusive_fp = True
#    2906
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/car_green_screen.jpg'

# %%
# Display the image
plt.imshow(image)

# %% [markdown]
# ### Define the color threshold

# %%
## TODO: Define our color selection boundaries in RGB values
lower_green = np.array([0,140,0]) 
upper_green = np.array([100,255,100])

# %% [markdown]
# ### Create a mask

# %%
# Define the masked area
mask = cv2.inRange(image, lower_green, upper_green)

# Vizualize the mask
plt.imshow(mask, cmap='gray')

# %%
# Mask the image to let the car show through
masked_image = np.copy(image)

masked_image[mask != 0] = [0, 0, 0]

# Display it!
plt.imshow(masked_image)

# %% [markdown]
# ### Mask and add a background image

# %%
# Load in a background image, and convert it to RGB 
background_image = mpimg.imread('images/sky.jpg')

background_image = cv2.cvtColor(background_image, cv2.COLOR_BGR2RGB)

## TODO: Crop it or resize the background to be the right size (450x660)
new_background_image=background_image[0:450,0:660]

## TODO: Mask the cropped background so that the pizza area is blocked
new_background_image[mask==0]=[0,0,0]
plt.imshow(new_background_image)
# Hint mask the opposite area of the previous image

## TODO: Display the background and make sure

# %% [markdown]
# ### Create a complete image

# %%
## TODO: Add the two images together to create a complete image!
complete_image = masked_image + new_background_image

plt.imshow(complete_image)
